# %% [markdown]
# **Exception Handling**
# in python allows you to handle erroe gracefully and takes corrective actions without stopping the execution of the program.

# %% [markdown]
# **What are Exception ? **
# Exception are the event theat disrupt the normal flow of programme.They occur when an error is encountered during programme execution.Common exception are
# -ZeroDivisionError:Dividing by zero
# -FileNotFoundError-File not Found
# -ValueError-Invalid Value
# TypeError-Invalid Type
