# %% [markdown]
# ## Polymorphism ##
# Polymorphism is a core concept of oops that allows object of different classes to be treated as objects of common super class.It provides a way to perform a single action in different forms.polymorphism is typically achieved through method overriding and interfaces.

# %% [markdown]
# ### Method Overriding
# Method overriding allows a child class to provide a specific implementation of a method that is already defined in its parent class

# %%
## Base class
class Animal:
    def speak(self):
        return "Some sound "

## Derived class1
class Dog(Animal):
    def speak(self):
        return "Woof!"

## Derived class2
class Cat(Animal):
    def speak(self):
        return "Meow!"
## Function that demonstrates polymorphism
def animal_speak(animal):
    return animal.speak()

dog=Dog()
cat=Cat()
print(dog.speak())  # Output: Woof!
print(cat.speak())  # Output: Meow!
print(animal_speak(dog))  # Output: Woof!# Demonstration of Polymorphism in Python
print(animal_speak(cat))  # Output: Meow!
# Out:
# Woof!
# Meow!
# Woof!
# Meow!

# %%
## polymorphism allows methods to do different things based on the object it is acting upon.
## Polymorphism  with functions and methods allows us to use a unified interface for different data types.
## Polymorphism  with functions and methods

class shape:
    def area(self):
        return"area of shape"

## derived class1
class rectangle(shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height
    def area(self):
        return self.width*self.height

## derived class2

class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
## function to demonstrate polymorphism
def calculate_area(shape):
    print("Area:",shape.area())

rect=rectangle(5,10)
circ=circle(7)
calculate_area(rect)  # Output: Area: 50
calculate_area(circ)  # Output: Area: 153.86
# Out:
# Area: 50
# Area: 153.86

# %% [markdown]
# ## Polymorphism with abstract base classes
# Abstract base class are used to define common methods for a group of related objects. They can enforce thst derived classes implement particular method , promoting consistency among different implementation,

# %%
## Polymorphism with abstract base classes
from abc import ABC, abstractmethod

class Vehicle(ABC):  
    @abstractmethod
    def start_engine(self):
        pass  

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"

## Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"

## Function demonstrating polymorphism
def start_vehicle_engine(vehicle_obj):
    print(vehicle_obj.start_engine())

## Create objects of derived classes
car = Car()
motorcycle = Motorcycle()

start_vehicle_engine(car)        # Output: Car engine started
start_vehicle_engine(motorcycle) # Output: Motorcycle engine started
# Out:
# Car engine started
# Motorcycle engine started
